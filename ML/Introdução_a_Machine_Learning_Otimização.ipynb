# %%
import pandas as pd
import numpy as np

# %%
uri = "https://gist.githubusercontent.com/guilhermesilveira/e99a526b2e7ccc6c3b70f53db43a87d2/raw/1605fc74aa778066bf2e6695e24d53cf65f2f447/machine-learning-carros-simulacao.csv"
dados = pd.read_csv(uri).drop(columns=["Unnamed: 0"], axis=1)
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano
# 0   30941.02        1               18  35085.22134
# 1   40557.96        1               20  12622.05362
# 2   89627.50        0               12  11440.79806
# 3   95276.14        0                3  43167.32682
# 4  117384.68        1                4  12770.11290

# %%
# situação horrível de "azar" onde as classes estão ordenadas por padrão

dados_azar = dados.sort_values("vendido", ascending=True)
x_azar = dados_azar[["preco", "idade_do_modelo","km_por_ano"]]
y_azar = dados_azar["vendido"]
dados_azar.head()
# Out:
#          preco  vendido  idade_do_modelo   km_por_ano
# 4999  74023.29        0               12  24812.80412
# 5322  84843.49        0               13  23095.63834
# 5319  83100.27        0               19  36240.72746
# 5316  87932.13        0               16  32249.56426
# 5315  77937.01        0               15  28414.50704

# %%
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyClassifier

SEED = 301
np.random.seed(SEED)

modelo = DummyClassifier()
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com dummy stratified, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com dummy stratified, 10 = [58.00, 58.00]

# %%
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier

SEED = 301
np.random.seed(SEED)

modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com cross validation, 10 = [73.83, 77.73]

# %%
# gerando dados elatorios de modelo de carro para simulacao de agrupamento ao usar nosso estimador

np.random.seed(SEED)
dados['modelo'] = dados.idade_do_modelo + np.random.randint(-2, 3, size=10000)
dados.modelo = dados.modelo + abs(dados.modelo.min()) + 1
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano  modelo
# 0   30941.02        1               18  35085.22134      18
# 1   40557.96        1               20  12622.05362      24
# 2   89627.50        0               12  11440.79806      14
# 3   95276.14        0                3  43167.32682       6
# 4  117384.68        1                4  12770.11290       5

# %%
def imprime_resultados(results):
  media = results['test_score'].mean() * 100
  desvio = results['test_score'].std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
# GroupKFold para analisar como o modelo se comporta com novos grupos

from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 75.78
# Intervalo [73.67, 77.90]

# %%
# GroupKFold em um pipeline com StandardScaler e SVC

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline

SEED = 301
np.random.seed(SEED)

scaler = StandardScaler()
modelo = SVC()

pipeline = Pipeline([('transformacao',scaler), ('estimador',modelo)])

cv = GroupKFold(n_splits = 10)
results = cross_validate(pipeline, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 76.68
# Intervalo [74.28, 79.08]

# %%
from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=3)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 78.67
# Intervalo [76.40, 80.94]

# %%
from sklearn.model_selection import GroupKFold

def roda_arvore_de_decisao(max_depth):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits = 10)
  modelo = DecisionTreeClassifier(max_depth=max_depth)
  results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
  print("max_depth = %d, media =%.2f" % (max_depth, results['test_score'].mean() * 100))



for i in range (1, 33):
      roda_arvore_de_decisao(i)
# Out:
# max_depth = 1, media =75.78
# max_depth = 2, media =75.78
# max_depth = 3, media =78.67
# max_depth = 4, media =78.63
# max_depth = 5, media =78.56
# max_depth = 6, media =78.12
# max_depth = 7, media =77.96
# max_depth = 8, media =77.86
# max_depth = 9, media =77.38
# max_depth = 10, media =77.19
# max_depth = 11, media =76.97
# max_depth = 12, media =76.49
# max_depth = 13, media =75.81
# max_depth = 14, media =75.66
# max_depth = 15, media =75.16
# max_depth = 16, media =75.11
# max_depth = 17, media =74.74
# max_depth = 18, media =74.33
# max_depth = 19, media =74.34
# max_depth = 20, media =74.22
# max_depth = 21, media =73.80
# max_depth = 22, media =73.81
# max_depth = 23, media =73.38
# max_depth = 24, media =73.43
# max_depth = 25, media =73.14
# max_depth = 26, media =73.04
# max_depth = 27, media =72.91
# max_depth = 28, media =72.66
# max_depth = 29, media =72.73
# max_depth = 30, media =72.81
# max_depth = 31, media =72.86
# max_depth = 32, media =72.52

# %%
from sklearn.model_selection import GroupKFold

def roda_arvore_de_decisao(max_depth):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits = 10)
  modelo = DecisionTreeClassifier(max_depth=max_depth)
  results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=True)
  train_score = results['train_score'].mean() * 100
  test_score = results['test_score'].mean() * 100
  print("Arvore max_depth = %d, treino = %.2f, teste = %.2f" % (max_depth, results['train_score'].mean() * 100, results['test_score'].mean() * 100))
  tabela = [max_depth, train_score, test_score]
  return tabela

resultados = [roda_arvore_de_decisao(i) for i in range (1, 33)]
resultados = pd.DataFrame(resultados, columns = ["max_depth", "train", "test"])
resultados.head()
# Out:
# Arvore max_depth = 1, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, treino = 75.79, teste = 75.78
# Arvore max_depth = 3, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, treino = 78.79, teste = 78.63
# Arvore max_depth = 5, treino = 78.94, teste = 78.56
# Arvore max_depth = 6, treino = 79.17, teste = 78.12
# Arvore max_depth = 7, treino = 79.50, teste = 77.96
# Arvore max_depth = 8, treino = 79.89, teste = 77.86
# Arvore max_depth = 9, treino = 80.46, teste = 77.38
# Arvore max_depth = 10, treino = 81.16, teste = 77.19
# Arvore max_depth = 11, treino = 82.03, teste = 76.97
# Arvore max_depth = 12, treino = 82.89, teste = 76.49
# Arvore max_depth = 13, treino = 83.95, teste = 75.81
# Arvore max_depth = 14, treino = 85.03, teste = 75.66
# Arvore max_depth = 15, treino = 86.14, teste = 75.16
# Arvore max_depth = 16, treino = 87.19, teste = 75.11
# Arvore max_depth = 17, treino = 88.31, teste = 74.74
# Arvore max_depth = 18, treino = 89.26, teste = 74.33
# Arvore max_depth = 19, treino = 90.32, teste = 74.34
# Arvore max_depth = 20, treino = 91.32, teste = 74.22
# Arvore max_depth = 21, treino = 92.14, teste = 73.80
# Arvore max_depth = 22, treino = 93.02, teste = 73.81
# Arvore max_depth = 23, treino = 93.80, teste = 73.38
# Arvore max_depth = 24, treino = 94.47, teste = 73.43
# Arvore max_depth = 25, treino = 95.16, teste = 73.14
# Arvore max_depth = 26, treino = 95.74, teste = 73.04
# Arvore max_depth = 27, treino = 96.33, teste = 72.91
# Arvore max_depth = 28, treino = 96.75, teste = 72.66
# Arvore max_depth = 29, treino = 97.10, teste = 72.73
# Arvore max_depth = 30, treino = 97.43, teste = 72.81
# Arvore max_depth = 31, treino = 97.80, teste = 72.86
# Arvore max_depth = 32, treino = 98.10, teste = 72.52
#    max_depth      train       test
# 0          1  75.791169  75.784219
# 1          2  75.791169  75.784219
# 2          3  78.750993  78.672633
# 3          4  78.787628  78.632803
# 4          5  78.941007  78.555912

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.lineplot(x = "max_depth", y = "train", data = resultados)
sns.lineplot(x = "max_depth", y = "test", data = resultados)
plt.legend(["Treino", "Teste"])

# %%
def roda_arvore_de_decisao(max_depth, min_samples_leaf):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits = 10)
  modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf = min_samples_leaf)
  results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=True)
  train_score = results['train_score'].mean() * 100
  test_score = results['test_score'].mean() * 100
  print("Arvore max_depth = %d, min_samples_leaf = %d, treino = %.2f, teste = %.2f" % (max_depth, min_samples_leaf, train_score, test_score))
  tabela = [max_depth, min_samples_leaf, train_score, test_score]
  return tabela

def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in range(1,33):
        tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf)
        resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns= ["max_depth","min_samples_leaf","train","test"])
  return resultados

resultados = busca()
resultados.head()
# Out:
# Arvore max_depth = 1, min_samples_leaf = 1, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 2, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 3, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 4, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 5, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 6, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 7, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 8, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 9, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 10, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 11, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 12, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 13, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 14, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 15, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 16, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 17, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 18, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 19, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 20, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 21, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 22, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 23, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 24, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 25, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 26, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 27, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 28, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 29, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 30, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 31, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 32, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 1, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 2, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 3, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 4, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 5, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 6, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 7, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 8, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 9, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 10, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 11, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 12, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 13, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 14, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 15, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 16, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 17, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 18, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 19, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 20, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 21, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 22, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 23, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 24, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 25, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 26, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 27, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 28, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 29, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 30, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 31, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 32, treino = 75.79, teste = 75.78
# Arvore max_depth = 3, min_samples_leaf = 1, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 2, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 3, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 4, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 5, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 6, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 7, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 8, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 9, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 10, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 11, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 12, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 13, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 14, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 15, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 16, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 17, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 18, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 19, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 20, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 21, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 22, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 23, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 24, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 25, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 26, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 27, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 28, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 29, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 30, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 31, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 32, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 1, treino = 78.79, teste = 78.63
# Arvore max_depth = 4, min_samples_leaf = 2, treino = 78.79, teste = 78.63
# Arvore max_depth = 4, min_samples_leaf = 3, treino = 78.77, teste = 78.57
# Arvore max_depth = 4, min_samples_leaf = 4, treino = 78.77, teste = 78.57
# Arvore max_depth = 4, min_samples_leaf = 5, treino = 78.76, teste = 78.59
# Arvore max_depth = 4, min_samples_leaf = 6, treino = 78.76, teste = 78.59
# Arvore max_depth = 4, min_samples_leaf = 7, treino = 78.76, teste = 78.59
# Arvore max_depth = 4, min_samples_leaf = 8, treino = 78.76, teste = 78.59
# Arvore max_depth = 4, min_samples_leaf = 9, treino = 78.76, teste = 78.59
# Arvore max_depth = 4, min_samples_leaf = 10, treino = 78.75, teste = 78.60
# Arvore max_depth = 4, min_samples_leaf = 11, treino = 78.75, teste = 78.64
# Arvore max_depth = 4, min_samples_leaf = 12, treino = 78.75, teste = 78.65
# Arvore max_depth = 4, min_samples_leaf = 13, treino = 78.75, teste = 78.65
# Arvore max_depth = 4, min_samples_leaf = 14, treino = 78.75, teste = 78.65
# Arvore max_depth = 4, min_samples_leaf = 15, treino = 78.75, teste = 78.65
# Arvore max_depth = 4, min_samples_leaf = 16, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 17, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 18, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 19, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 20, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 21, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 22, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 23, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 24, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 25, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 26, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 27, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 28, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 29, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 30, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 31, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 32, treino = 78.75, teste = 78.67
# Arvore max_depth = 5, min_samples_leaf = 1, treino = 78.94, teste = 78.56
# Arvore max_depth = 5, min_samples_leaf = 2, treino = 78.92, teste = 78.56
# Arvore max_depth = 5, min_samples_leaf = 3, treino = 78.91, teste = 78.47
# Arvore max_depth = 5, min_samples_leaf = 4, treino = 78.90, teste = 78.41
# Arvore max_depth = 5, min_samples_leaf = 5, treino = 78.88, teste = 78.34
# Arvore max_depth = 5, min_samples_leaf = 6, treino = 78.88, teste = 78.33
# Arvore max_depth = 5, min_samples_leaf = 7, treino = 78.87, teste = 78.33
# Arvore max_depth = 5, min_samples_leaf = 8, treino = 78.87, teste = 78.34
# Arvore max_depth = 5, min_samples_leaf = 9, treino = 78.85, teste = 78.40
# Arvore max_depth = 5, min_samples_leaf = 10, treino = 78.85, teste = 78.39
# Arvore max_depth = 5, min_samples_leaf = 11, treino = 78.84, teste = 78.49
# Arvore max_depth = 5, min_samples_leaf = 12, treino = 78.85, teste = 78.47
# Arvore max_depth = 5, min_samples_leaf = 13, treino = 78.85, teste = 78.47
# Arvore max_depth = 5, min_samples_leaf = 14, treino = 78.85, teste = 78.50
# Arvore max_depth = 5, min_samples_leaf = 15, treino = 78.85, teste = 78.46
# Arvore max_depth = 5, min_samples_leaf = 16, treino = 78.84, teste = 78.52
# Arvore max_depth = 5, min_samples_leaf = 17, treino = 78.84, teste = 78.51
# Arvore max_depth = 5, min_samples_leaf = 18, treino = 78.84, teste = 78.50
# Arvore max_depth = 5, min_samples_leaf = 19, treino = 78.84, teste = 78.50
# Arvore max_depth = 5, min_samples_leaf = 20, treino = 78.84, teste = 78.51
# Arvore max_depth = 5, min_samples_leaf = 21, treino = 78.84, teste = 78.54
# Arvore max_depth = 5, min_samples_leaf = 22, treino = 78.83, teste = 78.54
# Arvore max_depth = 5, min_samples_leaf = 23, treino = 78.83, teste = 78.54
# Arvore max_depth = 5, min_samples_leaf = 24, treino = 78.83, teste = 78.46
# Arvore max_depth = 5, min_samples_leaf = 25, treino = 78.83, teste = 78.41
# Arvore max_depth = 5, min_samples_leaf = 26, treino = 78.83, teste = 78.41
# Arvore max_depth = 5, min_samples_leaf = 27, treino = 78.83, teste = 78.45
# Arvore max_depth = 5, min_samples_leaf = 28, treino = 78.83, teste = 78.45
# Arvore max_depth = 5, min_samples_leaf = 29, treino = 78.83, teste = 78.45
# Arvore max_depth = 5, min_samples_leaf = 30, treino = 78.82, teste = 78.50
# Arvore max_depth = 5, min_samples_leaf = 31, treino = 78.82, teste = 78.50
# Arvore max_depth = 5, min_samples_leaf = 32, treino = 78.82, teste = 78.50
# Arvore max_depth = 6, min_samples_leaf = 1, treino = 79.17, teste = 78.12
# Arvore max_depth = 6, min_samples_leaf = 2, treino = 79.13, teste = 78.12
# Arvore max_depth = 6, min_samples_leaf = 3, treino = 79.14, teste = 77.98
# Arvore max_depth = 6, min_samples_leaf = 4, treino = 79.12, teste = 77.99
# Arvore max_depth = 6, min_samples_leaf = 5, treino = 79.11, teste = 77.92
# Arvore max_depth = 6, min_samples_leaf = 6, treino = 79.09, teste = 77.77
# Arvore max_depth = 6, min_samples_leaf = 7, treino = 79.09, teste = 77.74
# Arvore max_depth = 6, min_samples_leaf = 8, treino = 79.08, teste = 77.74
# Arvore max_depth = 6, min_samples_leaf = 9, treino = 79.08, teste = 77.75
# Arvore max_depth = 6, min_samples_leaf = 10, treino = 79.07, teste = 77.71
# Arvore max_depth = 6, min_samples_leaf = 11, treino = 79.05, teste = 77.79
# Arvore max_depth = 6, min_samples_leaf = 12, treino = 79.05, teste = 77.74
# Arvore max_depth = 6, min_samples_leaf = 13, treino = 79.05, teste = 77.77
# Arvore max_depth = 6, min_samples_leaf = 14, treino = 79.04, teste = 77.81
# Arvore max_depth = 6, min_samples_leaf = 15, treino = 79.03, teste = 77.85
# Arvore max_depth = 6, min_samples_leaf = 16, treino = 79.02, teste = 77.91
# Arvore max_depth = 6, min_samples_leaf = 17, treino = 79.01, teste = 77.93
# Arvore max_depth = 6, min_samples_leaf = 18, treino = 79.01, teste = 77.94
# Arvore max_depth = 6, min_samples_leaf = 19, treino = 79.02, teste = 77.90
# Arvore max_depth = 6, min_samples_leaf = 20, treino = 79.00, teste = 77.84
# Arvore max_depth = 6, min_samples_leaf = 21, treino = 78.99, teste = 77.80
# Arvore max_depth = 6, min_samples_leaf = 22, treino = 78.99, teste = 77.80
# Arvore max_depth = 6, min_samples_leaf = 23, treino = 78.98, teste = 77.88
# Arvore max_depth = 6, min_samples_leaf = 24, treino = 79.00, teste = 77.91
# Arvore max_depth = 6, min_samples_leaf = 25, treino = 79.01, teste = 77.80
# Arvore max_depth = 6, min_samples_leaf = 26, treino = 79.00, teste = 77.84
# Arvore max_depth = 6, min_samples_leaf = 27, treino = 78.98, teste = 77.86
# Arvore max_depth = 6, min_samples_leaf = 28, treino = 78.97, teste = 77.90
# Arvore max_depth = 6, min_samples_leaf = 29, treino = 78.97, teste = 77.89
# Arvore max_depth = 6, min_samples_leaf = 30, treino = 78.97, teste = 78.02
# Arvore max_depth = 6, min_samples_leaf = 31, treino = 78.96, teste = 78.03
# Arvore max_depth = 6, min_samples_leaf = 32, treino = 78.96, teste = 78.02
# Arvore max_depth = 7, min_samples_leaf = 1, treino = 79.50, teste = 77.96
# Arvore max_depth = 7, min_samples_leaf = 2, treino = 79.43, teste = 78.00
# Arvore max_depth = 7, min_samples_leaf = 3, treino = 79.42, teste = 77.85
# Arvore max_depth = 7, min_samples_leaf = 4, treino = 79.39, teste = 77.80
# Arvore max_depth = 7, min_samples_leaf = 5, treino = 79.39, teste = 77.75
# Arvore max_depth = 7, min_samples_leaf = 6, treino = 79.36, teste = 77.68
# Arvore max_depth = 7, min_samples_leaf = 7, treino = 79.34, teste = 77.63
# Arvore max_depth = 7, min_samples_leaf = 8, treino = 79.35, teste = 77.57
# Arvore max_depth = 7, min_samples_leaf = 9, treino = 79.34, teste = 77.65
# Arvore max_depth = 7, min_samples_leaf = 10, treino = 79.33, teste = 77.60
# Arvore max_depth = 7, min_samples_leaf = 11, treino = 79.34, teste = 77.77
# Arvore max_depth = 7, min_samples_leaf = 12, treino = 79.32, teste = 77.63
# Arvore max_depth = 7, min_samples_leaf = 13, treino = 79.33, teste = 77.58
# Arvore max_depth = 7, min_samples_leaf = 14, treino = 79.32, teste = 77.50
# Arvore max_depth = 7, min_samples_leaf = 15, treino = 79.33, teste = 77.52
# Arvore max_depth = 7, min_samples_leaf = 16, treino = 79.32, teste = 77.58
# Arvore max_depth = 7, min_samples_leaf = 17, treino = 79.30, teste = 77.64
# Arvore max_depth = 7, min_samples_leaf = 18, treino = 79.29, teste = 77.61
# Arvore max_depth = 7, min_samples_leaf = 19, treino = 79.29, teste = 77.67
# Arvore max_depth = 7, min_samples_leaf = 20, treino = 79.29, teste = 77.64
# Arvore max_depth = 7, min_samples_leaf = 21, treino = 79.28, teste = 77.61
# Arvore max_depth = 7, min_samples_leaf = 22, treino = 79.26, teste = 77.73
# Arvore max_depth = 7, min_samples_leaf = 23, treino = 79.26, teste = 77.86
# Arvore max_depth = 7, min_samples_leaf = 24, treino = 79.28, teste = 77.86
# Arvore max_depth = 7, min_samples_leaf = 25, treino = 79.27, teste = 77.83
# Arvore max_depth = 7, min_samples_leaf = 26, treino = 79.26, teste = 77.84
# Arvore max_depth = 7, min_samples_leaf = 27, treino = 79.26, teste = 77.82
# Arvore max_depth = 7, min_samples_leaf = 28, treino = 79.25, teste = 77.85
# Arvore max_depth = 7, min_samples_leaf = 29, treino = 79.25, teste = 77.83
# Arvore max_depth = 7, min_samples_leaf = 30, treino = 79.23, teste = 77.95
# Arvore max_depth = 7, min_samples_leaf = 31, treino = 79.22, teste = 77.91
# Arvore max_depth = 7, min_samples_leaf = 32, treino = 79.24, teste = 77.94
# Arvore max_depth = 8, min_samples_leaf = 1, treino = 79.89, teste = 77.86
# Arvore max_depth = 8, min_samples_leaf = 2, treino = 79.79, teste = 77.83
# Arvore max_depth = 8, min_samples_leaf = 3, treino = 79.80, teste = 77.59
# Arvore max_depth = 8, min_samples_leaf = 4, treino = 79.74, teste = 77.46
# Arvore max_depth = 8, min_samples_leaf = 5, treino = 79.70, teste = 77.31
# Arvore max_depth = 8, min_samples_leaf = 6, treino = 79.64, teste = 77.30
# Arvore max_depth = 8, min_samples_leaf = 7, treino = 79.60, teste = 77.35
# Arvore max_depth = 8, min_samples_leaf = 8, treino = 79.58, teste = 77.43
# Arvore max_depth = 8, min_samples_leaf = 9, treino = 79.58, teste = 77.55
# Arvore max_depth = 8, min_samples_leaf = 10, treino = 79.61, teste = 77.44
# Arvore max_depth = 8, min_samples_leaf = 11, treino = 79.62, teste = 77.67
# Arvore max_depth = 8, min_samples_leaf = 12, treino = 79.64, teste = 77.48
# Arvore max_depth = 8, min_samples_leaf = 13, treino = 79.67, teste = 77.67
# Arvore max_depth = 8, min_samples_leaf = 14, treino = 79.67, teste = 77.63
# Arvore max_depth = 8, min_samples_leaf = 15, treino = 79.67, teste = 77.68
# Arvore max_depth = 8, min_samples_leaf = 16, treino = 79.65, teste = 77.76
# Arvore max_depth = 8, min_samples_leaf = 17, treino = 79.63, teste = 77.79
# Arvore max_depth = 8, min_samples_leaf = 18, treino = 79.62, teste = 77.68
# Arvore max_depth = 8, min_samples_leaf = 19, treino = 79.59, teste = 77.61
# Arvore max_depth = 8, min_samples_leaf = 20, treino = 79.55, teste = 77.71
# Arvore max_depth = 8, min_samples_leaf = 21, treino = 79.52, teste = 77.63
# Arvore max_depth = 8, min_samples_leaf = 22, treino = 79.55, teste = 77.63
# Arvore max_depth = 8, min_samples_leaf = 23, treino = 79.55, teste = 77.80
# Arvore max_depth = 8, min_samples_leaf = 24, treino = 79.57, teste = 77.85
# Arvore max_depth = 8, min_samples_leaf = 25, treino = 79.55, teste = 77.70
# Arvore max_depth = 8, min_samples_leaf = 26, treino = 79.54, teste = 77.72
# Arvore max_depth = 8, min_samples_leaf = 27, treino = 79.51, teste = 77.72
# Arvore max_depth = 8, min_samples_leaf = 28, treino = 79.48, teste = 77.79
# Arvore max_depth = 8, min_samples_leaf = 29, treino = 79.48, teste = 77.76
# Arvore max_depth = 8, min_samples_leaf = 30, treino = 79.47, teste = 77.85
# Arvore max_depth = 8, min_samples_leaf = 31, treino = 79.45, teste = 77.89
# Arvore max_depth = 8, min_samples_leaf = 32, treino = 79.47, teste = 77.93
# Arvore max_depth = 9, min_samples_leaf = 1, treino = 80.46, teste = 77.38
# Arvore max_depth = 9, min_samples_leaf = 2, treino = 80.32, teste = 77.44
# Arvore max_depth = 9, min_samples_leaf = 3, treino = 80.32, teste = 77.20
# Arvore max_depth = 9, min_samples_leaf = 4, treino = 80.18, teste = 77.21
# Arvore max_depth = 9, min_samples_leaf = 5, treino = 80.12, teste = 77.24
# Arvore max_depth = 9, min_samples_leaf = 6, treino = 80.05, teste = 77.25
# Arvore max_depth = 9, min_samples_leaf = 7, treino = 80.00, teste = 77.15
# Arvore max_depth = 9, min_samples_leaf = 8, treino = 79.99, teste = 77.17
# Arvore max_depth = 9, min_samples_leaf = 9, treino = 79.98, teste = 77.26
# Arvore max_depth = 9, min_samples_leaf = 10, treino = 79.99, teste = 77.23
# Arvore max_depth = 9, min_samples_leaf = 11, treino = 79.97, teste = 77.36
# Arvore max_depth = 9, min_samples_leaf = 12, treino = 80.02, teste = 77.22
# Arvore max_depth = 9, min_samples_leaf = 13, treino = 80.05, teste = 77.25
# Arvore max_depth = 9, min_samples_leaf = 14, treino = 80.03, teste = 77.37
# Arvore max_depth = 9, min_samples_leaf = 15, treino = 80.02, teste = 77.35
# Arvore max_depth = 9, min_samples_leaf = 16, treino = 80.00, teste = 77.43
# Arvore max_depth = 9, min_samples_leaf = 17, treino = 79.98, teste = 77.34
# Arvore max_depth = 9, min_samples_leaf = 18, treino = 79.97, teste = 77.17
# Arvore max_depth = 9, min_samples_leaf = 19, treino = 79.94, teste = 77.24
# Arvore max_depth = 9, min_samples_leaf = 20, treino = 79.94, teste = 77.36
# Arvore max_depth = 9, min_samples_leaf = 21, treino = 79.94, teste = 77.04
# Arvore max_depth = 9, min_samples_leaf = 22, treino = 79.94, teste = 77.03
# Arvore max_depth = 9, min_samples_leaf = 23, treino = 79.92, teste = 77.23
# Arvore max_depth = 9, min_samples_leaf = 24, treino = 79.93, teste = 77.19
# Arvore max_depth = 9, min_samples_leaf = 25, treino = 79.91, teste = 77.21
# Arvore max_depth = 9, min_samples_leaf = 26, treino = 79.88, teste = 77.21
# Arvore max_depth = 9, min_samples_leaf = 27, treino = 79.84, teste = 77.14
# Arvore max_depth = 9, min_samples_leaf = 28, treino = 79.80, teste = 77.28
# Arvore max_depth = 9, min_samples_leaf = 29, treino = 79.80, teste = 77.27
# Arvore max_depth = 9, min_samples_leaf = 30, treino = 79.77, teste = 77.41
# Arvore max_depth = 9, min_samples_leaf = 31, treino = 79.74, teste = 77.47
# Arvore max_depth = 9, min_samples_leaf = 32, treino = 79.80, teste = 77.32
# Arvore max_depth = 10, min_samples_leaf = 1, treino = 81.16, teste = 77.19
# Arvore max_depth = 10, min_samples_leaf = 2, treino = 80.90, teste = 77.22
# Arvore max_depth = 10, min_samples_leaf = 3, treino = 80.85, teste = 77.15
# Arvore max_depth = 10, min_samples_leaf = 4, treino = 80.68, teste = 77.01
# Arvore max_depth = 10, min_samples_leaf = 5, treino = 80.54, teste = 76.85
# Arvore max_depth = 10, min_samples_leaf = 6, treino = 80.45, teste = 76.91
# Arvore max_depth = 10, min_samples_leaf = 7, treino = 80.36, teste = 77.00
# Arvore max_depth = 10, min_samples_leaf = 8, treino = 80.36, teste = 77.00
# Arvore max_depth = 10, min_samples_leaf = 9, treino = 80.33, teste = 76.97
# Arvore max_depth = 10, min_samples_leaf = 10, treino = 80.34, teste = 76.88
# Arvore max_depth = 10, min_samples_leaf = 11, treino = 80.34, teste = 76.78
# Arvore max_depth = 10, min_samples_leaf = 12, treino = 80.44, teste = 76.84
# Arvore max_depth = 10, min_samples_leaf = 13, treino = 80.46, teste = 76.99
# Arvore max_depth = 10, min_samples_leaf = 14, treino = 80.42, teste = 77.17
# Arvore max_depth = 10, min_samples_leaf = 15, treino = 80.43, teste = 77.24
# Arvore max_depth = 10, min_samples_leaf = 16, treino = 80.40, teste = 77.39
# Arvore max_depth = 10, min_samples_leaf = 17, treino = 80.36, teste = 77.47
# Arvore max_depth = 10, min_samples_leaf = 18, treino = 80.34, teste = 77.24
# Arvore max_depth = 10, min_samples_leaf = 19, treino = 80.30, teste = 77.22
# Arvore max_depth = 10, min_samples_leaf = 20, treino = 80.22, teste = 77.16
# Arvore max_depth = 10, min_samples_leaf = 21, treino = 80.23, teste = 77.08
# Arvore max_depth = 10, min_samples_leaf = 22, treino = 80.27, teste = 77.08
# Arvore max_depth = 10, min_samples_leaf = 23, treino = 80.25, teste = 77.27
# Arvore max_depth = 10, min_samples_leaf = 24, treino = 80.23, teste = 77.25
# Arvore max_depth = 10, min_samples_leaf = 25, treino = 80.19, teste = 77.24
# Arvore max_depth = 10, min_samples_leaf = 26, treino = 80.14, teste = 77.24
# Arvore max_depth = 10, min_samples_leaf = 27, treino = 80.12, teste = 77.19
# Arvore max_depth = 10, min_samples_leaf = 28, treino = 80.08, teste = 77.22
# Arvore max_depth = 10, min_samples_leaf = 29, treino = 80.07, teste = 77.23
# Arvore max_depth = 10, min_samples_leaf = 30, treino = 80.03, teste = 77.45
# Arvore max_depth = 10, min_samples_leaf = 31, treino = 79.98, teste = 77.47
# Arvore max_depth = 10, min_samples_leaf = 32, treino = 80.05, teste = 77.45
# Arvore max_depth = 11, min_samples_leaf = 1, treino = 82.03, teste = 76.97
# Arvore max_depth = 11, min_samples_leaf = 2, treino = 81.64, teste = 76.90
# Arvore max_depth = 11, min_samples_leaf = 3, treino = 81.52, teste = 76.64
# Arvore max_depth = 11, min_samples_leaf = 4, treino = 81.25, teste = 76.37
# Arvore max_depth = 11, min_samples_leaf = 5, treino = 81.09, teste = 76.22
# Arvore max_depth = 11, min_samples_leaf = 6, treino = 80.91, teste = 76.26
# Arvore max_depth = 11, min_samples_leaf = 7, treino = 80.78, teste = 76.42
# Arvore max_depth = 11, min_samples_leaf = 8, treino = 80.75, teste = 76.29
# Arvore max_depth = 11, min_samples_leaf = 9, treino = 80.73, teste = 76.40
# Arvore max_depth = 11, min_samples_leaf = 10, treino = 80.67, teste = 76.60
# Arvore max_depth = 11, min_samples_leaf = 11, treino = 80.66, teste = 76.73
# Arvore max_depth = 11, min_samples_leaf = 12, treino = 80.77, teste = 76.55
# Arvore max_depth = 11, min_samples_leaf = 13, treino = 80.81, teste = 76.92
# Arvore max_depth = 11, min_samples_leaf = 14, treino = 80.77, teste = 77.15
# Arvore max_depth = 11, min_samples_leaf = 15, treino = 80.74, teste = 77.20
# Arvore max_depth = 11, min_samples_leaf = 16, treino = 80.70, teste = 77.33
# Arvore max_depth = 11, min_samples_leaf = 17, treino = 80.64, teste = 77.32
# Arvore max_depth = 11, min_samples_leaf = 18, treino = 80.61, teste = 77.16
# Arvore max_depth = 11, min_samples_leaf = 19, treino = 80.57, teste = 77.11
# Arvore max_depth = 11, min_samples_leaf = 20, treino = 80.52, teste = 77.02
# Arvore max_depth = 11, min_samples_leaf = 21, treino = 80.52, teste = 76.85
# Arvore max_depth = 11, min_samples_leaf = 22, treino = 80.54, teste = 77.01
# Arvore max_depth = 11, min_samples_leaf = 23, treino = 80.51, teste = 77.16
# Arvore max_depth = 11, min_samples_leaf = 24, treino = 80.48, teste = 77.04
# Arvore max_depth = 11, min_samples_leaf = 25, treino = 80.45, teste = 77.12
# Arvore max_depth = 11, min_samples_leaf = 26, treino = 80.41, teste = 77.13
# Arvore max_depth = 11, min_samples_leaf = 27, treino = 80.37, teste = 77.08
# Arvore max_depth = 11, min_samples_leaf = 28, treino = 80.32, teste = 77.20
# Arvore max_depth = 11, min_samples_leaf = 29, treino = 80.29, teste = 77.13
# Arvore max_depth = 11, min_samples_leaf = 30, treino = 80.25, teste = 77.36
# Arvore max_depth = 11, min_samples_leaf = 31, treino = 80.21, teste = 77.30
# Arvore max_depth = 11, min_samples_leaf = 32, treino = 80.21, teste = 77.20
# Arvore max_depth = 12, min_samples_leaf = 1, treino = 82.89, teste = 76.49
# Arvore max_depth = 12, min_samples_leaf = 2, treino = 82.36, teste = 76.27
# Arvore max_depth = 12, min_samples_leaf = 3, treino = 82.11, teste = 76.33
# Arvore max_depth = 12, min_samples_leaf = 4, treino = 81.77, teste = 76.04
# Arvore max_depth = 12, min_samples_leaf = 5, treino = 81.56, teste = 75.97
# Arvore max_depth = 12, min_samples_leaf = 6, treino = 81.34, teste = 75.92
# Arvore max_depth = 12, min_samples_leaf = 7, treino = 81.22, teste = 76.10
# Arvore max_depth = 12, min_samples_leaf = 8, treino = 81.16, teste = 75.83
# Arvore max_depth = 12, min_samples_leaf = 9, treino = 81.12, teste = 75.96
# Arvore max_depth = 12, min_samples_leaf = 10, treino = 81.09, teste = 76.30
# Arvore max_depth = 12, min_samples_leaf = 11, treino = 81.13, teste = 76.22
# Arvore max_depth = 12, min_samples_leaf = 12, treino = 81.18, teste = 76.29
# Arvore max_depth = 12, min_samples_leaf = 13, treino = 81.15, teste = 76.44
# Arvore max_depth = 12, min_samples_leaf = 14, treino = 81.09, teste = 76.68
# Arvore max_depth = 12, min_samples_leaf = 15, treino = 81.04, teste = 76.84
# Arvore max_depth = 12, min_samples_leaf = 16, treino = 81.02, teste = 76.92
# Arvore max_depth = 12, min_samples_leaf = 17, treino = 80.93, teste = 77.12
# Arvore max_depth = 12, min_samples_leaf = 18, treino = 80.87, teste = 76.98
# Arvore max_depth = 12, min_samples_leaf = 19, treino = 80.82, teste = 76.98
# Arvore max_depth = 12, min_samples_leaf = 20, treino = 80.75, teste = 76.89
# Arvore max_depth = 12, min_samples_leaf = 21, treino = 80.78, teste = 76.94
# Arvore max_depth = 12, min_samples_leaf = 22, treino = 80.77, teste = 77.10
# Arvore max_depth = 12, min_samples_leaf = 23, treino = 80.74, teste = 77.36
# Arvore max_depth = 12, min_samples_leaf = 24, treino = 80.70, teste = 77.25
# Arvore max_depth = 12, min_samples_leaf = 25, treino = 80.63, teste = 77.21
# Arvore max_depth = 12, min_samples_leaf = 26, treino = 80.59, teste = 77.21
# Arvore max_depth = 12, min_samples_leaf = 27, treino = 80.53, teste = 77.09
# Arvore max_depth = 12, min_samples_leaf = 28, treino = 80.46, teste = 77.12
# Arvore max_depth = 12, min_samples_leaf = 29, treino = 80.40, teste = 77.07
# Arvore max_depth = 12, min_samples_leaf = 30, treino = 80.35, teste = 77.27
# Arvore max_depth = 12, min_samples_leaf = 31, treino = 80.31, teste = 77.29
# Arvore max_depth = 12, min_samples_leaf = 32, treino = 80.34, teste = 77.00
# Arvore max_depth = 13, min_samples_leaf = 1, treino = 83.95, teste = 75.81
# Arvore max_depth = 13, min_samples_leaf = 2, treino = 83.21, teste = 75.43
# Arvore max_depth = 13, min_samples_leaf = 3, treino = 82.86, teste = 75.74
# Arvore max_depth = 13, min_samples_leaf = 4, treino = 82.40, teste = 75.63
# Arvore max_depth = 13, min_samples_leaf = 5, treino = 82.10, teste = 75.46
# Arvore max_depth = 13, min_samples_leaf = 6, treino = 81.88, teste = 75.65
# Arvore max_depth = 13, min_samples_leaf = 7, treino = 81.73, teste = 75.83
# Arvore max_depth = 13, min_samples_leaf = 8, treino = 81.63, teste = 75.79
# Arvore max_depth = 13, min_samples_leaf = 9, treino = 81.58, teste = 75.84
# Arvore max_depth = 13, min_samples_leaf = 10, treino = 81.47, teste = 76.06
# Arvore max_depth = 13, min_samples_leaf = 11, treino = 81.50, teste = 76.20
# Arvore max_depth = 13, min_samples_leaf = 12, treino = 81.51, teste = 76.27
# Arvore max_depth = 13, min_samples_leaf = 13, treino = 81.47, teste = 76.52
# Arvore max_depth = 13, min_samples_leaf = 14, treino = 81.37, teste = 76.83
# Arvore max_depth = 13, min_samples_leaf = 15, treino = 81.33, teste = 76.82
# Arvore max_depth = 13, min_samples_leaf = 16, treino = 81.28, teste = 76.74
# Arvore max_depth = 13, min_samples_leaf = 17, treino = 81.17, teste = 76.96
# Arvore max_depth = 13, min_samples_leaf = 18, treino = 81.06, teste = 77.04
# Arvore max_depth = 13, min_samples_leaf = 19, treino = 80.98, teste = 76.91
# Arvore max_depth = 13, min_samples_leaf = 20, treino = 80.90, teste = 76.85
# Arvore max_depth = 13, min_samples_leaf = 21, treino = 80.92, teste = 76.86
# Arvore max_depth = 13, min_samples_leaf = 22, treino = 80.89, teste = 77.02
# Arvore max_depth = 13, min_samples_leaf = 23, treino = 80.85, teste = 77.29
# Arvore max_depth = 13, min_samples_leaf = 24, treino = 80.80, teste = 77.04
# Arvore max_depth = 13, min_samples_leaf = 25, treino = 80.73, teste = 77.12
# Arvore max_depth = 13, min_samples_leaf = 26, treino = 80.71, teste = 77.12
# Arvore max_depth = 13, min_samples_leaf = 27, treino = 80.66, teste = 77.05
# Arvore max_depth = 13, min_samples_leaf = 28, treino = 80.61, teste = 77.02
# Arvore max_depth = 13, min_samples_leaf = 29, treino = 80.56, teste = 76.99
# Arvore max_depth = 13, min_samples_leaf = 30, treino = 80.50, teste = 77.12
# Arvore max_depth = 13, min_samples_leaf = 31, treino = 80.44, teste = 77.06
# Arvore max_depth = 13, min_samples_leaf = 32, treino = 80.51, teste = 76.85
# Arvore max_depth = 14, min_samples_leaf = 1, treino = 85.03, teste = 75.66
# Arvore max_depth = 14, min_samples_leaf = 2, treino = 84.03, teste = 75.38
# Arvore max_depth = 14, min_samples_leaf = 3, treino = 83.55, teste = 75.59
# Arvore max_depth = 14, min_samples_leaf = 4, treino = 83.02, teste = 75.41
# Arvore max_depth = 14, min_samples_leaf = 5, treino = 82.72, teste = 75.22
# Arvore max_depth = 14, min_samples_leaf = 6, treino = 82.41, teste = 75.49
# Arvore max_depth = 14, min_samples_leaf = 7, treino = 82.24, teste = 75.85
# Arvore max_depth = 14, min_samples_leaf = 8, treino = 82.07, teste = 75.53
# Arvore max_depth = 14, min_samples_leaf = 9, treino = 82.00, teste = 75.73
# Arvore max_depth = 14, min_samples_leaf = 10, treino = 81.84, teste = 75.93
# Arvore max_depth = 14, min_samples_leaf = 11, treino = 81.82, teste = 76.03
# Arvore max_depth = 14, min_samples_leaf = 12, treino = 81.79, teste = 76.17
# Arvore max_depth = 14, min_samples_leaf = 13, treino = 81.77, teste = 76.41
# Arvore max_depth = 14, min_samples_leaf = 14, treino = 81.65, teste = 76.70
# Arvore max_depth = 14, min_samples_leaf = 15, treino = 81.59, teste = 76.77
# Arvore max_depth = 14, min_samples_leaf = 16, treino = 81.49, teste = 76.64
# Arvore max_depth = 14, min_samples_leaf = 17, treino = 81.37, teste = 76.95
# Arvore max_depth = 14, min_samples_leaf = 18, treino = 81.22, teste = 76.93
# Arvore max_depth = 14, min_samples_leaf = 19, treino = 81.14, teste = 76.85
# Arvore max_depth = 14, min_samples_leaf = 20, treino = 81.05, teste = 76.68
# Arvore max_depth = 14, min_samples_leaf = 21, treino = 81.06, teste = 76.61
# Arvore max_depth = 14, min_samples_leaf = 22, treino = 81.03, teste = 76.67
# Arvore max_depth = 14, min_samples_leaf = 23, treino = 81.00, teste = 77.00
# Arvore max_depth = 14, min_samples_leaf = 24, treino = 80.95, teste = 77.01
# Arvore max_depth = 14, min_samples_leaf = 25, treino = 80.87, teste = 77.07
# Arvore max_depth = 14, min_samples_leaf = 26, treino = 80.85, teste = 77.09
# Arvore max_depth = 14, min_samples_leaf = 27, treino = 80.78, teste = 77.10
# Arvore max_depth = 14, min_samples_leaf = 28, treino = 80.72, teste = 77.11
# Arvore max_depth = 14, min_samples_leaf = 29, treino = 80.66, teste = 76.94
# Arvore max_depth = 14, min_samples_leaf = 30, treino = 80.59, teste = 77.23
# Arvore max_depth = 14, min_samples_leaf = 31, treino = 80.53, teste = 77.22
# Arvore max_depth = 14, min_samples_leaf = 32, treino = 80.60, teste = 76.69
# Arvore max_depth = 15, min_samples_leaf = 1, treino = 86.14, teste = 75.16
# Arvore max_depth = 15, min_samples_leaf = 2, treino = 84.90, teste = 74.96
# Arvore max_depth = 15, min_samples_leaf = 3, treino = 84.31, teste = 74.80
# Arvore max_depth = 15, min_samples_leaf = 4, treino = 83.71, teste = 74.96
# Arvore max_depth = 15, min_samples_leaf = 5, treino = 83.29, teste = 75.12
# Arvore max_depth = 15, min_samples_leaf = 6, treino = 82.94, teste = 75.31
# Arvore max_depth = 15, min_samples_leaf = 7, treino = 82.73, teste = 75.64
# Arvore max_depth = 15, min_samples_leaf = 8, treino = 82.47, teste = 75.15
# Arvore max_depth = 15, min_samples_leaf = 9, treino = 82.35, teste = 75.43
# Arvore max_depth = 15, min_samples_leaf = 10, treino = 82.14, teste = 75.78
# Arvore max_depth = 15, min_samples_leaf = 11, treino = 82.09, teste = 76.12
# Arvore max_depth = 15, min_samples_leaf = 12, treino = 82.04, teste = 75.98
# Arvore max_depth = 15, min_samples_leaf = 13, treino = 82.00, teste = 76.14
# Arvore max_depth = 15, min_samples_leaf = 14, treino = 81.86, teste = 76.45
# Arvore max_depth = 15, min_samples_leaf = 15, treino = 81.80, teste = 76.44
# Arvore max_depth = 15, min_samples_leaf = 16, treino = 81.69, teste = 76.59
# Arvore max_depth = 15, min_samples_leaf = 17, treino = 81.57, teste = 76.84
# Arvore max_depth = 15, min_samples_leaf = 18, treino = 81.40, teste = 76.79
# Arvore max_depth = 15, min_samples_leaf = 19, treino = 81.29, teste = 76.74
# Arvore max_depth = 15, min_samples_leaf = 20, treino = 81.21, teste = 76.52
# Arvore max_depth = 15, min_samples_leaf = 21, treino = 81.21, teste = 76.53
# Arvore max_depth = 15, min_samples_leaf = 22, treino = 81.18, teste = 76.53
# Arvore max_depth = 15, min_samples_leaf = 23, treino = 81.11, teste = 76.94
# Arvore max_depth = 15, min_samples_leaf = 24, treino = 81.06, teste = 76.99
# Arvore max_depth = 15, min_samples_leaf = 25, treino = 80.96, teste = 77.11
# Arvore max_depth = 15, min_samples_leaf = 26, treino = 80.94, teste = 77.18
# Arvore max_depth = 15, min_samples_leaf = 27, treino = 80.88, teste = 77.16
# Arvore max_depth = 15, min_samples_leaf = 28, treino = 80.81, teste = 77.00
# Arvore max_depth = 15, min_samples_leaf = 29, treino = 80.76, teste = 76.87
# Arvore max_depth = 15, min_samples_leaf = 30, treino = 80.70, teste = 77.27
# Arvore max_depth = 15, min_samples_leaf = 31, treino = 80.65, teste = 77.19
# Arvore max_depth = 15, min_samples_leaf = 32, treino = 80.70, teste = 76.88
# Arvore max_depth = 16, min_samples_leaf = 1, treino = 87.19, teste = 75.11
# Arvore max_depth = 16, min_samples_leaf = 2, treino = 85.70, teste = 74.65
# Arvore max_depth = 16, min_samples_leaf = 3, treino = 84.99, teste = 74.82
# Arvore max_depth = 16, min_samples_leaf = 4, treino = 84.27, teste = 74.92
# Arvore max_depth = 16, min_samples_leaf = 5, treino = 83.81, teste = 75.08
# Arvore max_depth = 16, min_samples_leaf = 6, treino = 83.40, teste = 75.23
# Arvore max_depth = 16, min_samples_leaf = 7, treino = 83.19, teste = 75.70
# Arvore max_depth = 16, min_samples_leaf = 8, treino = 82.90, teste = 74.99
# Arvore max_depth = 16, min_samples_leaf = 9, treino = 82.76, teste = 75.22
# Arvore max_depth = 16, min_samples_leaf = 10, treino = 82.51, teste = 75.52
# Arvore max_depth = 16, min_samples_leaf = 11, treino = 82.39, teste = 75.72
# Arvore max_depth = 16, min_samples_leaf = 12, treino = 82.29, teste = 75.75
# Arvore max_depth = 16, min_samples_leaf = 13, treino = 82.24, teste = 75.89
# Arvore max_depth = 16, min_samples_leaf = 14, treino = 82.12, teste = 76.48
# Arvore max_depth = 16, min_samples_leaf = 15, treino = 82.02, teste = 76.40
# Arvore max_depth = 16, min_samples_leaf = 16, treino = 81.94, teste = 76.49
# Arvore max_depth = 16, min_samples_leaf = 17, treino = 81.79, teste = 76.73
# Arvore max_depth = 16, min_samples_leaf = 18, treino = 81.61, teste = 76.58
# Arvore max_depth = 16, min_samples_leaf = 19, treino = 81.49, teste = 76.36
# Arvore max_depth = 16, min_samples_leaf = 20, treino = 81.41, teste = 76.25
# Arvore max_depth = 16, min_samples_leaf = 21, treino = 81.38, teste = 76.35
# Arvore max_depth = 16, min_samples_leaf = 22, treino = 81.33, teste = 76.48
# Arvore max_depth = 16, min_samples_leaf = 23, treino = 81.25, teste = 76.93
# Arvore max_depth = 16, min_samples_leaf = 24, treino = 81.18, teste = 76.87
# Arvore max_depth = 16, min_samples_leaf = 25, treino = 81.07, teste = 77.05
# Arvore max_depth = 16, min_samples_leaf = 26, treino = 81.04, teste = 77.17
# Arvore max_depth = 16, min_samples_leaf = 27, treino = 80.96, teste = 77.11
# Arvore max_depth = 16, min_samples_leaf = 28, treino = 80.91, teste = 77.10
# Arvore max_depth = 16, min_samples_leaf = 29, treino = 80.85, teste = 76.97
# Arvore max_depth = 16, min_samples_leaf = 30, treino = 80.77, teste = 77.30
# Arvore max_depth = 16, min_samples_leaf = 31, treino = 80.72, teste = 77.26
# Arvore max_depth = 16, min_samples_leaf = 32, treino = 80.76, teste = 76.87
# Arvore max_depth = 17, min_samples_leaf = 1, treino = 88.31, teste = 74.74
# Arvore max_depth = 17, min_samples_leaf = 2, treino = 86.50, teste = 74.01
# Arvore max_depth = 17, min_samples_leaf = 3, treino = 85.72, teste = 74.31
# Arvore max_depth = 17, min_samples_leaf = 4, treino = 84.89, teste = 74.49
# Arvore max_depth = 17, min_samples_leaf = 5, treino = 84.37, teste = 74.84
# Arvore max_depth = 17, min_samples_leaf = 6, treino = 83.84, teste = 75.16
# Arvore max_depth = 17, min_samples_leaf = 7, treino = 83.53, teste = 75.40
# Arvore max_depth = 17, min_samples_leaf = 8, treino = 83.24, teste = 74.86
# Arvore max_depth = 17, min_samples_leaf = 9, treino = 83.09, teste = 75.13
# Arvore max_depth = 17, min_samples_leaf = 10, treino = 82.83, teste = 75.27
# Arvore max_depth = 17, min_samples_leaf = 11, treino = 82.67, teste = 75.72
# Arvore max_depth = 17, min_samples_leaf = 12, treino = 82.53, teste = 75.87
# Arvore max_depth = 17, min_samples_leaf = 13, treino = 82.51, teste = 75.87
# Arvore max_depth = 17, min_samples_leaf = 14, treino = 82.33, teste = 76.50
# Arvore max_depth = 17, min_samples_leaf = 15, treino = 82.25, teste = 76.51
# Arvore max_depth = 17, min_samples_leaf = 16, treino = 82.12, teste = 76.33
# Arvore max_depth = 17, min_samples_leaf = 17, treino = 81.97, teste = 76.77
# Arvore max_depth = 17, min_samples_leaf = 18, treino = 81.79, teste = 76.78
# Arvore max_depth = 17, min_samples_leaf = 19, treino = 81.68, teste = 76.69
# Arvore max_depth = 17, min_samples_leaf = 20, treino = 81.59, teste = 76.53
# Arvore max_depth = 17, min_samples_leaf = 21, treino = 81.55, teste = 76.40
# Arvore max_depth = 17, min_samples_leaf = 22, treino = 81.50, teste = 76.67
# Arvore max_depth = 17, min_samples_leaf = 23, treino = 81.40, teste = 77.17
# Arvore max_depth = 17, min_samples_leaf = 24, treino = 81.32, teste = 77.02
# Arvore max_depth = 17, min_samples_leaf = 25, treino = 81.19, teste = 77.18
# Arvore max_depth = 17, min_samples_leaf = 26, treino = 81.12, teste = 77.28
# Arvore max_depth = 17, min_samples_leaf = 27, treino = 81.06, teste = 77.19
# Arvore max_depth = 17, min_samples_leaf = 28, treino = 80.98, teste = 77.09
# Arvore max_depth = 17, min_samples_leaf = 29, treino = 80.91, teste = 76.95
# Arvore max_depth = 17, min_samples_leaf = 30, treino = 80.83, teste = 77.30
# Arvore max_depth = 17, min_samples_leaf = 31, treino = 80.77, teste = 77.20
# Arvore max_depth = 17, min_samples_leaf = 32, treino = 80.82, teste = 76.98
# Arvore max_depth = 18, min_samples_leaf = 1, treino = 89.26, teste = 74.33
# Arvore max_depth = 18, min_samples_leaf = 2, treino = 87.25, teste = 73.84
# Arvore max_depth = 18, min_samples_leaf = 3, treino = 86.41, teste = 74.10
# Arvore max_depth = 18, min_samples_leaf = 4, treino = 85.43, teste = 74.42
# Arvore max_depth = 18, min_samples_leaf = 5, treino = 84.81, teste = 74.47
# Arvore max_depth = 18, min_samples_leaf = 6, treino = 84.23, teste = 74.83
# Arvore max_depth = 18, min_samples_leaf = 7, treino = 83.91, teste = 75.18
# Arvore max_depth = 18, min_samples_leaf = 8, treino = 83.62, teste = 74.66
# Arvore max_depth = 18, min_samples_leaf = 9, treino = 83.40, teste = 75.00
# Arvore max_depth = 18, min_samples_leaf = 10, treino = 83.06, teste = 75.14
# Arvore max_depth = 18, min_samples_leaf = 11, treino = 82.86, teste = 75.66
# Arvore max_depth = 18, min_samples_leaf = 12, treino = 82.70, teste = 75.84
# Arvore max_depth = 18, min_samples_leaf = 13, treino = 82.68, teste = 75.85
# Arvore max_depth = 18, min_samples_leaf = 14, treino = 82.51, teste = 76.36
# Arvore max_depth = 18, min_samples_leaf = 15, treino = 82.37, teste = 76.45
# Arvore max_depth = 18, min_samples_leaf = 16, treino = 82.25, teste = 76.44
# Arvore max_depth = 18, min_samples_leaf = 17, treino = 82.07, teste = 76.73
# Arvore max_depth = 18, min_samples_leaf = 18, treino = 81.93, teste = 76.51
# Arvore max_depth = 18, min_samples_leaf = 19, treino = 81.83, teste = 76.46
# Arvore max_depth = 18, min_samples_leaf = 20, treino = 81.73, teste = 76.38
# Arvore max_depth = 18, min_samples_leaf = 21, treino = 81.70, teste = 76.42
# Arvore max_depth = 18, min_samples_leaf = 22, treino = 81.58, teste = 76.76
# Arvore max_depth = 18, min_samples_leaf = 23, treino = 81.48, teste = 77.12
# Arvore max_depth = 18, min_samples_leaf = 24, treino = 81.39, teste = 77.05
# Arvore max_depth = 18, min_samples_leaf = 25, treino = 81.28, teste = 77.19
# Arvore max_depth = 18, min_samples_leaf = 26, treino = 81.19, teste = 77.24
# Arvore max_depth = 18, min_samples_leaf = 27, treino = 81.11, teste = 77.18
# Arvore max_depth = 18, min_samples_leaf = 28, treino = 81.03, teste = 77.14
# Arvore max_depth = 18, min_samples_leaf = 29, treino = 80.97, teste = 77.05
# Arvore max_depth = 18, min_samples_leaf = 30, treino = 80.87, teste = 77.38
# Arvore max_depth = 18, min_samples_leaf = 31, treino = 80.82, teste = 77.27
# Arvore max_depth = 18, min_samples_leaf = 32, treino = 80.85, teste = 76.86
# Arvore max_depth = 19, min_samples_leaf = 1, treino = 90.32, teste = 74.34
# Arvore max_depth = 19, min_samples_leaf = 2, treino = 88.01, teste = 73.65
# Arvore max_depth = 19, min_samples_leaf = 3, treino = 87.02, teste = 74.09
# Arvore max_depth = 19, min_samples_leaf = 4, treino = 85.89, teste = 73.93
# Arvore max_depth = 19, min_samples_leaf = 5, treino = 85.24, teste = 74.16
# Arvore max_depth = 19, min_samples_leaf = 6, treino = 84.59, teste = 74.40
# Arvore max_depth = 19, min_samples_leaf = 7, treino = 84.25, teste = 75.00
# Arvore max_depth = 19, min_samples_leaf = 8, treino = 83.91, teste = 74.49
# Arvore max_depth = 19, min_samples_leaf = 9, treino = 83.68, teste = 74.83
# Arvore max_depth = 19, min_samples_leaf = 10, treino = 83.30, teste = 74.99
# Arvore max_depth = 19, min_samples_leaf = 11, treino = 83.04, teste = 75.58
# Arvore max_depth = 19, min_samples_leaf = 12, treino = 82.89, teste = 75.59
# Arvore max_depth = 19, min_samples_leaf = 13, treino = 82.86, teste = 75.64
# Arvore max_depth = 19, min_samples_leaf = 14, treino = 82.64, teste = 76.37
# Arvore max_depth = 19, min_samples_leaf = 15, treino = 82.45, teste = 76.40
# Arvore max_depth = 19, min_samples_leaf = 16, treino = 82.33, teste = 76.45
# Arvore max_depth = 19, min_samples_leaf = 17, treino = 82.15, teste = 76.66
# Arvore max_depth = 19, min_samples_leaf = 18, treino = 82.04, teste = 76.43
# Arvore max_depth = 19, min_samples_leaf = 19, treino = 81.95, teste = 76.43
# Arvore max_depth = 19, min_samples_leaf = 20, treino = 81.82, teste = 76.32
# Arvore max_depth = 19, min_samples_leaf = 21, treino = 81.77, teste = 76.37
# Arvore max_depth = 19, min_samples_leaf = 22, treino = 81.63, teste = 76.72
# Arvore max_depth = 19, min_samples_leaf = 23, treino = 81.52, teste = 77.10
# Arvore max_depth = 19, min_samples_leaf = 24, treino = 81.42, teste = 77.01
# Arvore max_depth = 19, min_samples_leaf = 25, treino = 81.34, teste = 77.19
# Arvore max_depth = 19, min_samples_leaf = 26, treino = 81.23, teste = 77.15
# Arvore max_depth = 19, min_samples_leaf = 27, treino = 81.16, teste = 77.11
# Arvore max_depth = 19, min_samples_leaf = 28, treino = 81.10, teste = 77.09
# Arvore max_depth = 19, min_samples_leaf = 29, treino = 81.01, teste = 76.94
# Arvore max_depth = 19, min_samples_leaf = 30, treino = 80.91, teste = 77.25
# Arvore max_depth = 19, min_samples_leaf = 31, treino = 80.85, teste = 77.14
# Arvore max_depth = 19, min_samples_leaf = 32, treino = 80.86, teste = 76.89
# Arvore max_depth = 20, min_samples_leaf = 1, treino = 91.32, teste = 74.22
# Arvore max_depth = 20, min_samples_leaf = 2, treino = 88.67, teste = 73.36
# Arvore max_depth = 20, min_samples_leaf = 3, treino = 87.54, teste = 73.70
# Arvore max_depth = 20, min_samples_leaf = 4, treino = 86.34, teste = 73.87
# Arvore max_depth = 20, min_samples_leaf = 5, treino = 85.61, teste = 74.31
# Arvore max_depth = 20, min_samples_leaf = 6, treino = 84.96, teste = 74.66
# Arvore max_depth = 20, min_samples_leaf = 7, treino = 84.55, teste = 75.15
# Arvore max_depth = 20, min_samples_leaf = 8, treino = 84.17, teste = 74.38
# Arvore max_depth = 20, min_samples_leaf = 9, treino = 83.88, teste = 74.64
# Arvore max_depth = 20, min_samples_leaf = 10, treino = 83.48, teste = 74.97
# Arvore max_depth = 20, min_samples_leaf = 11, treino = 83.18, teste = 75.61
# Arvore max_depth = 20, min_samples_leaf = 12, treino = 83.03, teste = 75.65
# Arvore max_depth = 20, min_samples_leaf = 13, treino = 83.00, teste = 75.87
# Arvore max_depth = 20, min_samples_leaf = 14, treino = 82.73, teste = 76.32
# Arvore max_depth = 20, min_samples_leaf = 15, treino = 82.55, teste = 76.29
# Arvore max_depth = 20, min_samples_leaf = 16, treino = 82.39, teste = 76.16
# Arvore max_depth = 20, min_samples_leaf = 17, treino = 82.22, teste = 76.59
# Arvore max_depth = 20, min_samples_leaf = 18, treino = 82.13, teste = 76.43
# Arvore max_depth = 20, min_samples_leaf = 19, treino = 82.04, teste = 76.37
# Arvore max_depth = 20, min_samples_leaf = 20, treino = 81.90, teste = 76.27
# Arvore max_depth = 20, min_samples_leaf = 21, treino = 81.85, teste = 76.39
# Arvore max_depth = 20, min_samples_leaf = 22, treino = 81.67, teste = 76.69
# Arvore max_depth = 20, min_samples_leaf = 23, treino = 81.55, teste = 77.08
# Arvore max_depth = 20, min_samples_leaf = 24, treino = 81.46, teste = 77.02
# Arvore max_depth = 20, min_samples_leaf = 25, treino = 81.37, teste = 77.18
# Arvore max_depth = 20, min_samples_leaf = 26, treino = 81.25, teste = 77.17
# Arvore max_depth = 20, min_samples_leaf = 27, treino = 81.19, teste = 77.11
# Arvore max_depth = 20, min_samples_leaf = 28, treino = 81.13, teste = 77.04
# Arvore max_depth = 20, min_samples_leaf = 29, treino = 81.05, teste = 76.91
# ...
# Arvore max_depth = 26, min_samples_leaf = 18, treino = 82.29, teste = 76.38
# Arvore max_depth = 26, min_samples_leaf = 19, treino = 82.15, teste = 76.25
# Arvore max_depth = 26, min_samples_leaf = 20, treino = 82.01, teste = 76.16
# Arvore max_depth = 26, min_samples_leaf = 21, treino = 81.92, teste = 76.32
# Arvore max_depth = 26, min_samples_leaf = 22, treino = 81.76, teste = 76.59
# Arvore max_depth = 26, min_samples_leaf = 23, treino = 81.65, teste = 77.00
# Arvore max_depth = 26, min_samples_leaf = 24, treino = 81.55, teste = 76.92
# Arvore max_depth = 26, min_samples_leaf = 25, treino = 81.46, teste = 77.04
# Arvore max_depth = 26, min_samples_leaf = 26, treino = 81.36, teste = 77.05
# Arvore max_depth = 26, min_samples_leaf = 27, treino = 81.28, teste = 77.00
# Arvore max_depth = 26, min_samples_leaf = 28, treino = 81.20, teste = 76.98
# Arvore max_depth = 26, min_samples_leaf = 29, treino = 81.12, teste = 76.85
# Arvore max_depth = 26, min_samples_leaf = 30, treino = 81.01, teste = 77.12
# Arvore max_depth = 26, min_samples_leaf = 31, treino = 80.95, teste = 77.01
# Arvore max_depth = 26, min_samples_leaf = 32, treino = 80.89, teste = 76.84
# Arvore max_depth = 27, min_samples_leaf = 1, treino = 96.33, teste = 72.91
# Arvore max_depth = 27, min_samples_leaf = 2, treino = 92.12, teste = 72.44
# Arvore max_depth = 27, min_samples_leaf = 3, treino = 90.27, teste = 72.98
# Arvore max_depth = 27, min_samples_leaf = 4, treino = 88.41, teste = 73.41
# Arvore max_depth = 27, min_samples_leaf = 5, treino = 87.42, teste = 73.63
# Arvore max_depth = 27, min_samples_leaf = 6, treino = 86.47, teste = 73.89
# Arvore max_depth = 27, min_samples_leaf = 7, treino = 85.87, teste = 74.49
# Arvore max_depth = 27, min_samples_leaf = 8, treino = 85.36, teste = 73.85
# Arvore max_depth = 27, min_samples_leaf = 9, treino = 84.78, teste = 74.51
# Arvore max_depth = 27, min_samples_leaf = 10, treino = 84.28, teste = 74.89
# Arvore max_depth = 27, min_samples_leaf = 11, treino = 83.85, teste = 75.68
# Arvore max_depth = 27, min_samples_leaf = 12, treino = 83.57, teste = 75.43
# Arvore max_depth = 27, min_samples_leaf = 13, treino = 83.35, teste = 75.59
# Arvore max_depth = 27, min_samples_leaf = 14, treino = 82.97, teste = 76.38
# Arvore max_depth = 27, min_samples_leaf = 15, treino = 82.78, teste = 76.29
# Arvore max_depth = 27, min_samples_leaf = 16, treino = 82.61, teste = 76.15
# Arvore max_depth = 27, min_samples_leaf = 17, treino = 82.42, teste = 76.50
# Arvore max_depth = 27, min_samples_leaf = 18, treino = 82.31, teste = 76.44
# Arvore max_depth = 27, min_samples_leaf = 19, treino = 82.15, teste = 76.26
# Arvore max_depth = 27, min_samples_leaf = 20, treino = 82.01, teste = 76.17
# Arvore max_depth = 27, min_samples_leaf = 21, treino = 81.92, teste = 76.32
# Arvore max_depth = 27, min_samples_leaf = 22, treino = 81.77, teste = 76.58
# Arvore max_depth = 27, min_samples_leaf = 23, treino = 81.65, teste = 76.99
# Arvore max_depth = 27, min_samples_leaf = 24, treino = 81.55, teste = 76.91
# Arvore max_depth = 27, min_samples_leaf = 25, treino = 81.46, teste = 77.03
# Arvore max_depth = 27, min_samples_leaf = 26, treino = 81.36, teste = 77.04
# Arvore max_depth = 27, min_samples_leaf = 27, treino = 81.28, teste = 76.99
# Arvore max_depth = 27, min_samples_leaf = 28, treino = 81.20, teste = 76.98
# Arvore max_depth = 27, min_samples_leaf = 29, treino = 81.12, teste = 76.85
# Arvore max_depth = 27, min_samples_leaf = 30, treino = 81.01, teste = 77.12
# Arvore max_depth = 27, min_samples_leaf = 31, treino = 80.95, teste = 77.01
# Arvore max_depth = 27, min_samples_leaf = 32, treino = 80.89, teste = 76.84
# Arvore max_depth = 28, min_samples_leaf = 1, treino = 96.75, teste = 72.66
# Arvore max_depth = 28, min_samples_leaf = 2, treino = 92.39, teste = 72.33
# Arvore max_depth = 28, min_samples_leaf = 3, treino = 90.51, teste = 72.92
# Arvore max_depth = 28, min_samples_leaf = 4, treino = 88.57, teste = 73.21
# Arvore max_depth = 28, min_samples_leaf = 5, treino = 87.56, teste = 73.64
# Arvore max_depth = 28, min_samples_leaf = 6, treino = 86.59, teste = 73.84
# Arvore max_depth = 28, min_samples_leaf = 7, treino = 85.96, teste = 74.61
# Arvore max_depth = 28, min_samples_leaf = 8, treino = 85.38, teste = 73.78
# Arvore max_depth = 28, min_samples_leaf = 9, treino = 84.82, teste = 74.54
# Arvore max_depth = 28, min_samples_leaf = 10, treino = 84.33, teste = 74.79
# Arvore max_depth = 28, min_samples_leaf = 11, treino = 83.89, teste = 75.57
# Arvore max_depth = 28, min_samples_leaf = 12, treino = 83.60, teste = 75.46
# Arvore max_depth = 28, min_samples_leaf = 13, treino = 83.36, teste = 75.59
# Arvore max_depth = 28, min_samples_leaf = 14, treino = 82.98, teste = 76.32
# Arvore max_depth = 28, min_samples_leaf = 15, treino = 82.80, teste = 76.23
# Arvore max_depth = 28, min_samples_leaf = 16, treino = 82.63, teste = 76.11
# Arvore max_depth = 28, min_samples_leaf = 17, treino = 82.43, teste = 76.47
# Arvore max_depth = 28, min_samples_leaf = 18, treino = 82.32, teste = 76.39
# Arvore max_depth = 28, min_samples_leaf = 19, treino = 82.16, teste = 76.27
# Arvore max_depth = 28, min_samples_leaf = 20, treino = 82.02, teste = 76.18
# Arvore max_depth = 28, min_samples_leaf = 21, treino = 81.92, teste = 76.32
# Arvore max_depth = 28, min_samples_leaf = 22, treino = 81.77, teste = 76.60
# Arvore max_depth = 28, min_samples_leaf = 23, treino = 81.65, teste = 77.01
# Arvore max_depth = 28, min_samples_leaf = 24, treino = 81.56, teste = 76.93
# Arvore max_depth = 28, min_samples_leaf = 25, treino = 81.46, teste = 77.05
# Arvore max_depth = 28, min_samples_leaf = 26, treino = 81.36, teste = 77.06
# Arvore max_depth = 28, min_samples_leaf = 27, treino = 81.28, teste = 76.99
# Arvore max_depth = 28, min_samples_leaf = 28, treino = 81.20, teste = 76.98
# Arvore max_depth = 28, min_samples_leaf = 29, treino = 81.12, teste = 76.85
# Arvore max_depth = 28, min_samples_leaf = 30, treino = 81.01, teste = 77.12
# Arvore max_depth = 28, min_samples_leaf = 31, treino = 80.95, teste = 77.01
# Arvore max_depth = 28, min_samples_leaf = 32, treino = 80.89, teste = 76.84
# Arvore max_depth = 29, min_samples_leaf = 1, treino = 97.10, teste = 72.73
# Arvore max_depth = 29, min_samples_leaf = 2, treino = 92.65, teste = 72.21
# Arvore max_depth = 29, min_samples_leaf = 3, treino = 90.69, teste = 72.71
# Arvore max_depth = 29, min_samples_leaf = 4, treino = 88.69, teste = 73.28
# Arvore max_depth = 29, min_samples_leaf = 5, treino = 87.66, teste = 73.57
# Arvore max_depth = 29, min_samples_leaf = 6, treino = 86.68, teste = 73.76
# Arvore max_depth = 29, min_samples_leaf = 7, treino = 86.02, teste = 74.58
# Arvore max_depth = 29, min_samples_leaf = 8, treino = 85.43, teste = 73.84
# Arvore max_depth = 29, min_samples_leaf = 9, treino = 84.87, teste = 74.44
# Arvore max_depth = 29, min_samples_leaf = 10, treino = 84.35, teste = 74.78
# Arvore max_depth = 29, min_samples_leaf = 11, treino = 83.93, teste = 75.65
# Arvore max_depth = 29, min_samples_leaf = 12, treino = 83.61, teste = 75.46
# Arvore max_depth = 29, min_samples_leaf = 13, treino = 83.36, teste = 75.61
# Arvore max_depth = 29, min_samples_leaf = 14, treino = 82.99, teste = 76.31
# Arvore max_depth = 29, min_samples_leaf = 15, treino = 82.81, teste = 76.23
# Arvore max_depth = 29, min_samples_leaf = 16, treino = 82.65, teste = 76.11
# Arvore max_depth = 29, min_samples_leaf = 17, treino = 82.44, teste = 76.47
# Arvore max_depth = 29, min_samples_leaf = 18, treino = 82.32, teste = 76.39
# Arvore max_depth = 29, min_samples_leaf = 19, treino = 82.16, teste = 76.27
# Arvore max_depth = 29, min_samples_leaf = 20, treino = 82.02, teste = 76.18
# Arvore max_depth = 29, min_samples_leaf = 21, treino = 81.92, teste = 76.32
# Arvore max_depth = 29, min_samples_leaf = 22, treino = 81.77, teste = 76.63
# Arvore max_depth = 29, min_samples_leaf = 23, treino = 81.66, teste = 77.04
# Arvore max_depth = 29, min_samples_leaf = 24, treino = 81.56, teste = 76.96
# Arvore max_depth = 29, min_samples_leaf = 25, treino = 81.47, teste = 77.08
# Arvore max_depth = 29, min_samples_leaf = 26, treino = 81.37, teste = 77.09
# Arvore max_depth = 29, min_samples_leaf = 27, treino = 81.29, teste = 77.02
# Arvore max_depth = 29, min_samples_leaf = 28, treino = 81.20, teste = 76.98
# Arvore max_depth = 29, min_samples_leaf = 29, treino = 81.12, teste = 76.85
# Arvore max_depth = 29, min_samples_leaf = 30, treino = 81.01, teste = 77.12
# Arvore max_depth = 29, min_samples_leaf = 31, treino = 80.95, teste = 77.01
# Arvore max_depth = 29, min_samples_leaf = 32, treino = 80.89, teste = 76.84
# Arvore max_depth = 30, min_samples_leaf = 1, treino = 97.43, teste = 72.81
# Arvore max_depth = 30, min_samples_leaf = 2, treino = 92.81, teste = 72.21
# Arvore max_depth = 30, min_samples_leaf = 3, treino = 90.83, teste = 72.89
# Arvore max_depth = 30, min_samples_leaf = 4, treino = 88.84, teste = 73.25
# Arvore max_depth = 30, min_samples_leaf = 5, treino = 87.76, teste = 73.54
# Arvore max_depth = 30, min_samples_leaf = 6, treino = 86.74, teste = 73.91
# Arvore max_depth = 30, min_samples_leaf = 7, treino = 86.10, teste = 74.59
# Arvore max_depth = 30, min_samples_leaf = 8, treino = 85.46, teste = 73.77
# Arvore max_depth = 30, min_samples_leaf = 9, treino = 84.89, teste = 74.44
# Arvore max_depth = 30, min_samples_leaf = 10, treino = 84.37, teste = 74.81
# Arvore max_depth = 30, min_samples_leaf = 11, treino = 83.95, teste = 75.63
# Arvore max_depth = 30, min_samples_leaf = 12, treino = 83.62, teste = 75.52
# Arvore max_depth = 30, min_samples_leaf = 13, treino = 83.37, teste = 75.59
# Arvore max_depth = 30, min_samples_leaf = 14, treino = 82.99, teste = 76.30
# Arvore max_depth = 30, min_samples_leaf = 15, treino = 82.82, teste = 76.25
# Arvore max_depth = 30, min_samples_leaf = 16, treino = 82.65, teste = 76.13
# Arvore max_depth = 30, min_samples_leaf = 17, treino = 82.44, teste = 76.49
# Arvore max_depth = 30, min_samples_leaf = 18, treino = 82.32, teste = 76.43
# Arvore max_depth = 30, min_samples_leaf = 19, treino = 82.16, teste = 76.27
# Arvore max_depth = 30, min_samples_leaf = 20, treino = 82.02, teste = 76.18
# Arvore max_depth = 30, min_samples_leaf = 21, treino = 81.92, teste = 76.32
# Arvore max_depth = 30, min_samples_leaf = 22, treino = 81.78, teste = 76.61
# Arvore max_depth = 30, min_samples_leaf = 23, treino = 81.66, teste = 77.02
# Arvore max_depth = 30, min_samples_leaf = 24, treino = 81.56, teste = 76.96
# Arvore max_depth = 30, min_samples_leaf = 25, treino = 81.47, teste = 77.08
# Arvore max_depth = 30, min_samples_leaf = 26, treino = 81.37, teste = 77.09
# Arvore max_depth = 30, min_samples_leaf = 27, treino = 81.29, teste = 77.02
# Arvore max_depth = 30, min_samples_leaf = 28, treino = 81.20, teste = 76.98
# Arvore max_depth = 30, min_samples_leaf = 29, treino = 81.12, teste = 76.85
# Arvore max_depth = 30, min_samples_leaf = 30, treino = 81.01, teste = 77.12
# Arvore max_depth = 30, min_samples_leaf = 31, treino = 80.95, teste = 77.01
# Arvore max_depth = 30, min_samples_leaf = 32, treino = 80.89, teste = 76.84
# Arvore max_depth = 31, min_samples_leaf = 1, treino = 97.80, teste = 72.86
# Arvore max_depth = 31, min_samples_leaf = 2, treino = 93.04, teste = 72.26
# Arvore max_depth = 31, min_samples_leaf = 3, treino = 90.96, teste = 72.95
# Arvore max_depth = 31, min_samples_leaf = 4, treino = 88.94, teste = 73.21
# Arvore max_depth = 31, min_samples_leaf = 5, treino = 87.84, teste = 73.59
# Arvore max_depth = 31, min_samples_leaf = 6, treino = 86.81, teste = 73.79
# Arvore max_depth = 31, min_samples_leaf = 7, treino = 86.15, teste = 74.52
# Arvore max_depth = 31, min_samples_leaf = 8, treino = 85.49, teste = 73.83
# Arvore max_depth = 31, min_samples_leaf = 9, treino = 84.89, teste = 74.48
# Arvore max_depth = 31, min_samples_leaf = 10, treino = 84.38, teste = 74.80
# Arvore max_depth = 31, min_samples_leaf = 11, treino = 83.97, teste = 75.64
# Arvore max_depth = 31, min_samples_leaf = 12, treino = 83.63, teste = 75.52
# Arvore max_depth = 31, min_samples_leaf = 13, treino = 83.37, teste = 75.58
# Arvore max_depth = 31, min_samples_leaf = 14, treino = 83.00, teste = 76.29
# Arvore max_depth = 31, min_samples_leaf = 15, treino = 82.82, teste = 76.25
# Arvore max_depth = 31, min_samples_leaf = 16, treino = 82.65, teste = 76.13
# Arvore max_depth = 31, min_samples_leaf = 17, treino = 82.44, teste = 76.49
# Arvore max_depth = 31, min_samples_leaf = 18, treino = 82.32, teste = 76.41
# Arvore max_depth = 31, min_samples_leaf = 19, treino = 82.16, teste = 76.27
# Arvore max_depth = 31, min_samples_leaf = 20, treino = 82.02, teste = 76.18
# Arvore max_depth = 31, min_samples_leaf = 21, treino = 81.92, teste = 76.32
# Arvore max_depth = 31, min_samples_leaf = 22, treino = 81.78, teste = 76.61
# Arvore max_depth = 31, min_samples_leaf = 23, treino = 81.66, teste = 77.02
# Arvore max_depth = 31, min_samples_leaf = 24, treino = 81.56, teste = 76.96
# Arvore max_depth = 31, min_samples_leaf = 25, treino = 81.47, teste = 77.08
# Arvore max_depth = 31, min_samples_leaf = 26, treino = 81.37, teste = 77.09
# Arvore max_depth = 31, min_samples_leaf = 27, treino = 81.29, teste = 77.02
# Arvore max_depth = 31, min_samples_leaf = 28, treino = 81.20, teste = 76.98
# Arvore max_depth = 31, min_samples_leaf = 29, treino = 81.12, teste = 76.85
# Arvore max_depth = 31, min_samples_leaf = 30, treino = 81.01, teste = 77.12
# Arvore max_depth = 31, min_samples_leaf = 31, treino = 80.95, teste = 77.01
# Arvore max_depth = 31, min_samples_leaf = 32, treino = 80.89, teste = 76.84
# Arvore max_depth = 32, min_samples_leaf = 1, treino = 98.10, teste = 72.52
# Arvore max_depth = 32, min_samples_leaf = 2, treino = 93.24, teste = 72.25
# Arvore max_depth = 32, min_samples_leaf = 3, treino = 91.13, teste = 72.76
# Arvore max_depth = 32, min_samples_leaf = 4, treino = 89.03, teste = 73.04
# Arvore max_depth = 32, min_samples_leaf = 5, treino = 87.89, teste = 73.59
# Arvore max_depth = 32, min_samples_leaf = 6, treino = 86.83, teste = 73.85
# Arvore max_depth = 32, min_samples_leaf = 7, treino = 86.19, teste = 74.58
# Arvore max_depth = 32, min_samples_leaf = 8, treino = 85.49, teste = 73.79
# Arvore max_depth = 32, min_samples_leaf = 9, treino = 84.89, teste = 74.48
# Arvore max_depth = 32, min_samples_leaf = 10, treino = 84.38, teste = 74.83
# Arvore max_depth = 32, min_samples_leaf = 11, treino = 83.98, teste = 75.62
# Arvore max_depth = 32, min_samples_leaf = 12, treino = 83.63, teste = 75.52
# Arvore max_depth = 32, min_samples_leaf = 13, treino = 83.37, teste = 75.58
# Arvore max_depth = 32, min_samples_leaf = 14, treino = 83.00, teste = 76.29
# Arvore max_depth = 32, min_samples_leaf = 15, treino = 82.82, teste = 76.26
# Arvore max_depth = 32, min_samples_leaf = 16, treino = 82.65, teste = 76.13
# Arvore max_depth = 32, min_samples_leaf = 17, treino = 82.44, teste = 76.49
# Arvore max_depth = 32, min_samples_leaf = 18, treino = 82.32, teste = 76.41
# Arvore max_depth = 32, min_samples_leaf = 19, treino = 82.16, teste = 76.27
# Arvore max_depth = 32, min_samples_leaf = 20, treino = 82.02, teste = 76.18
# Arvore max_depth = 32, min_samples_leaf = 21, treino = 81.92, teste = 76.32
# Arvore max_depth = 32, min_samples_leaf = 22, treino = 81.78, teste = 76.61
# Arvore max_depth = 32, min_samples_leaf = 23, treino = 81.66, teste = 77.02
# Arvore max_depth = 32, min_samples_leaf = 24, treino = 81.56, teste = 76.96
# Arvore max_depth = 32, min_samples_leaf = 25, treino = 81.47, teste = 77.08
# Arvore max_depth = 32, min_samples_leaf = 26, treino = 81.37, teste = 77.09
# Arvore max_depth = 32, min_samples_leaf = 27, treino = 81.29, teste = 77.02
# Arvore max_depth = 32, min_samples_leaf = 28, treino = 81.20, teste = 76.98
# Arvore max_depth = 32, min_samples_leaf = 29, treino = 81.12, teste = 76.85
# Arvore max_depth = 32, min_samples_leaf = 30, treino = 81.01, teste = 77.12
# Arvore max_depth = 32, min_samples_leaf = 31, treino = 80.95, teste = 77.01
# Arvore max_depth = 32, min_samples_leaf = 32, treino = 80.89, teste = 76.84
#    max_depth  min_samples_leaf      train       test
# 0          1                 1  75.791169  75.784219
# 1          1                 2  75.791169  75.784219
# 2          1                 3  75.791169  75.784219
# 3          1                 4  75.791169  75.784219
# 4          1                 5  75.791169  75.784219

# %%
def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [32, 64, 128, 256]:
      tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf)
      resultados.append(tabela)
      
  resultados = pd.DataFrame(resultados, columns= ["max_depth","min_samples_leaf","train","test"])
  return resultados

# %%
resultados.sort_values("test", ascending=False).head()
# Out:
#      max_depth  min_samples_leaf      train       test
# 123          4                28  78.750993  78.672633
# 126          4                31  78.750993  78.672633
# 85           3                22  78.750993  78.672633
# 84           3                21  78.750993  78.672633
# 83           3                20  78.750993  78.672633

# %%
pd.plotting.scatter_matrix(resultados, figsize = (14, 8), alpha = 0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f772460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f1b5310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f1dc730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f180fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f131400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f159730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f159820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f101ca0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f0dc490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f085880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f032c70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f061100>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1f01b4f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1efc88e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1ef76d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1ef31160>]],
#       dtype=object)

# %%
sns.pairplot(resultados)

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-db34b24cd1a1> in <module>
#       8
#       9 # Generate a mask for the upper triangle
# ---> 10 mask = np.zeros_like(corr, dtype=np.bool)
#      11 mask[np.triu_indices_from(mask)] = True
#      12
#
# NameError: name 'corr' is not defined

# %%
def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [128, 192, 256, 512]:
        tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf)
        resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns= ["max_depth","min_samples_leaf","train","test"])
  return resultados

resultados = busca()
resultados.head()
# Out:
# Arvore max_depth = 1, min_samples_leaf = 128, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 192, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 256, treino = 75.79, teste = 75.78
# Arvore max_depth = 1, min_samples_leaf = 512, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 128, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 192, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 256, treino = 75.79, teste = 75.78
# Arvore max_depth = 2, min_samples_leaf = 512, treino = 75.79, teste = 75.78
# Arvore max_depth = 3, min_samples_leaf = 128, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 192, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 256, treino = 78.75, teste = 78.67
# Arvore max_depth = 3, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 4, min_samples_leaf = 128, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 192, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 256, treino = 78.75, teste = 78.67
# Arvore max_depth = 4, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 5, min_samples_leaf = 128, treino = 78.77, teste = 78.44
# Arvore max_depth = 5, min_samples_leaf = 192, treino = 78.77, teste = 78.44
# Arvore max_depth = 5, min_samples_leaf = 256, treino = 78.77, teste = 78.44
# Arvore max_depth = 5, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 6, min_samples_leaf = 128, treino = 78.85, teste = 78.27
# Arvore max_depth = 6, min_samples_leaf = 192, treino = 78.79, teste = 78.31
# Arvore max_depth = 6, min_samples_leaf = 256, treino = 78.79, teste = 78.27
# Arvore max_depth = 6, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 7, min_samples_leaf = 128, treino = 79.01, teste = 78.21
# Arvore max_depth = 7, min_samples_leaf = 192, treino = 78.92, teste = 78.10
# Arvore max_depth = 7, min_samples_leaf = 256, treino = 78.85, teste = 78.08
# Arvore max_depth = 7, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 8, min_samples_leaf = 128, treino = 79.05, teste = 78.37
# Arvore max_depth = 8, min_samples_leaf = 192, treino = 78.98, teste = 78.20
# Arvore max_depth = 8, min_samples_leaf = 256, treino = 78.89, teste = 77.94
# Arvore max_depth = 8, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 9, min_samples_leaf = 128, treino = 79.12, teste = 78.30
# Arvore max_depth = 9, min_samples_leaf = 192, treino = 78.99, teste = 78.11
# Arvore max_depth = 9, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 9, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 10, min_samples_leaf = 128, treino = 79.16, teste = 78.29
# Arvore max_depth = 10, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 10, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 10, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 11, min_samples_leaf = 128, treino = 79.19, teste = 78.31
# Arvore max_depth = 11, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 11, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 11, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 12, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 12, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 12, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 12, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 13, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 13, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 13, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 13, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 14, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 14, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 14, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 14, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 15, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 15, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 15, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 15, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 16, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 16, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 16, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 16, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 17, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 17, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 17, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 17, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 18, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 18, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 18, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 18, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 19, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 19, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 19, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 19, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 20, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 20, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 20, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 20, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 21, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 21, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 21, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 21, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 22, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 22, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 22, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 22, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 23, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 23, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 23, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 23, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 24, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 24, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 24, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 24, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 25, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 25, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 25, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 25, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 26, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 26, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 26, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 26, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 27, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 27, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 27, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 27, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 28, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 28, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 28, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 28, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 29, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 29, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 29, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 29, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 30, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 30, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 30, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 30, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 31, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 31, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 31, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 31, min_samples_leaf = 512, treino = 77.53, teste = 77.50
# Arvore max_depth = 32, min_samples_leaf = 128, treino = 79.21, teste = 78.22
# Arvore max_depth = 32, min_samples_leaf = 192, treino = 79.01, teste = 78.05
# Arvore max_depth = 32, min_samples_leaf = 256, treino = 78.90, teste = 77.85
# Arvore max_depth = 32, min_samples_leaf = 512, treino = 77.53, teste = 77.50
#    max_depth  min_samples_leaf      train       test
# 0          1               128  75.791169  75.784219
# 1          1               192  75.791169  75.784219
# 2          1               256  75.791169  75.784219
# 3          1               512  75.791169  75.784219
# 4          2               128  75.791169  75.784219

# %%
def roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits = 10)
  modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf = min_samples_leaf, min_samples_split = min_samples_split)
  results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=True)
  train_score = results['train_score'].mean() * 100
  test_score = results['test_score'].mean() * 100

  tabela = [max_depth, min_samples_leaf, min_samples_split, train_score, test_score]
  return tabela

def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [32, 64, 128, 256]:
        for min_samples_split in [32, 64, 128, 256]:
          tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split)
          resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns= ["max_depth","min_samples_leaf", "min_samples_split", "train","test"])
  return resultados

resultados = busca()
resultados.head()
# Out:
#    max_depth  min_samples_leaf  min_samples_split      train       test
# 0          1                32                 32  75.791169  75.784219
# 1          1                32                 64  75.791169  75.784219
# 2          1                32                128  75.791169  75.784219
# 3          1                32                256  75.791169  75.784219
# 4          1                64                 32  75.791169  75.784219

# %%
def roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits = 10)
  modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf = min_samples_leaf, min_samples_split = min_samples_split)
  results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=True)
  fit_time = results['fit_time'].mean()
  score_time = results['score_time'].mean()
  train_score = results['train_score'].mean() * 100
  test_score = results['test_score'].mean() * 100

  tabela = [max_depth, min_samples_leaf, min_samples_split, train_score, test_score, fit_time, score_time]
  return tabela

def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [32, 64, 128, 256]:
        for min_samples_split in [32, 64, 128, 256]:
          tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split)
          resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns= ["max_depth","min_samples_leaf", "min_samples_split", "train","test", "fit_time", "score_time"])
  return resultados

resultados = busca()
resultados.head()
# Out:
#    max_depth  min_samples_leaf  min_samples_split      train       test  \
# 0          1                32                 32  75.791169  75.784219
# 1          1                32                 64  75.791169  75.784219
# 2          1                32                128  75.791169  75.784219
# 3          1                32                256  75.791169  75.784219
# 4          1                64                 32  75.791169  75.784219
#
#    fit_time  score_time
# 0  0.008055    0.003043
# 1  0.006927    0.002343
# 2  0.007303    0.002722
# 3  0.007498    0.002646
# 4  0.007420    0.002335

# %%
from sklearn.model_selection import GridSearchCV

SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]

}

busca = GridSearchCV(DecisionTreeClassifier(),
                    espaco_de_parametros,
                    cv = GroupKFold(n_splits = 10))

busca.fit(x_azar, y_azar,groups = dados.modelo)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.012277      0.000950         0.002446        0.000085
# 1       0.013843      0.002311         0.003206        0.000850
# 2       0.012991      0.001573         0.002663        0.000272
# 3       0.012684      0.000769         0.002682        0.000370
# 4       0.012707      0.001273         0.002902        0.000681
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               3                     32
# 1            gini               3                     32
# 2            gini               3                     32
# 3            gini               3                     64
# 4            gini               3                     64
#
#   param_min_samples_split                                             params  \
# 0                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 1                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 2                     128  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 3                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 4                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
#
#    split0_test_score  ...  split3_test_score  split4_test_score  \
# 0           0.804757  ...            0.78408           0.783181
# 1           0.804757  ...            0.78408           0.783181
# 2           0.804757  ...            0.78408           0.783181
# 3           0.804757  ...            0.78408           0.783181
# 4           0.804757  ...            0.78408           0.783181
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.797809           0.762866           0.781818            0.77551
# 1           0.797809           0.762866           0.781818            0.77551
# 2           0.797809           0.762866           0.781818            0.77551
# 3           0.797809           0.762866           0.781818            0.77551
# 4           0.797809           0.762866           0.781818            0.77551
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.790262         0.786726        0.011361                1
# 1           0.790262         0.786726        0.011361                1
# 2           0.790262         0.786726        0.011361                1
# 3           0.790262         0.786726        0.011361                1
# 4           0.790262         0.786726        0.011361                1
#
# [5 rows x 22 columns]

# %%
print(busca.best_params_)
print(busca.best_score_ * 100)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 78.67263337284332

# %%
DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
            max_features=None, max_leaf_nodes=None,
            min_impurity_decrease=0.0,
            min_samples_leaf=32, min_samples_split=32,
            min_weight_fraction_leaf=0.0, random_state=None,
            splitter='best')
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=32, min_samples_split=32)

# %%
from sklearn.metrics import accuracy_score 

predicoes = melhor.predict(x_azar) 
accuracy = accuracy_score(predicoes, y_azar) * 100

print("Accuracy para os dados foi %.2f%%" % accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-80eea5ad94e1> in <module>
#       1 from sklearn.metrics import accuracy_score
#       2
# ----> 3 predicoes = melhor.predict(x_azar)
#       4 accuracy = accuracy_score(predicoes, y_azar) * 100
#       5
#
# NameError: name 'melhor' is not defined

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(busca, x_azar, y_azar, cv = GroupKFold(n_splits=10), groups = dados.modelo)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]

}

busca = GridSearchCV(DecisionTreeClassifier(),
                    espaco_de_parametros,
                    cv = KFold(n_splits = 5, shuffle=True))

busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
scores

# %%
def imprime_score(scores):
  media = scores.mean() * 100
  desvio = scores.std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
from sklearn.tree import export_graphviz
import graphviz


features = x_azar.columns
dot_data = export_graphviz(melhor, out_file=None, filled=True, rounded=True,
                          class_names=["não","sim"],
                          feature_names=features)
graph = graphviz.Source(dot_data)
graph
